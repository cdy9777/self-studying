# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %% [markdown]
# ## 1. 그래프 기본

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show() ## 객체에 대한 설명을 보고 싶지 않을 때

# %% [markdown]
# ## 제목

# %%
plt.plot(x,y)
plt.title("test")
# Out:
# Text(0.5, 1.0, 'test')

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams["font.family"] = "Malgun Gothic" # windows
# matplotlib.rcParams["font.family"] = "AppleGothic" # Mac인 경우
matplotlib.rcParams["font.size"] = 15
matplotlib.rcParams["axes.unicode_minus"] = False # 글씨체를 한글로 바꾸었을 때 -(마이너스) 깨짐 현상 방지

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist #사용가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmsy10',
#  'STIXGeneral',
#  'cmtt10',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'cmmi10',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'cmex10',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'STIXSizeFourSym',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'cmss10',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'cmr10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Display',
#  'Segoe Print',
#  'Cambria',
#  'Times New Roman',
#  'Rockwell Condensed',
#  'OCR A Extended',
#  'Gill Sans MT',
#  'HYsnrL',
#  'Comic Sans MS',
#  'Castellar',
#  'Bodoni MT',
#  'HYgtrE',
#  'Segoe UI',
#  'Arial Unicode MS',
#  'Bauhaus 93',
# ...

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-2, -1, 0],[2,4,8])
